# %%
import pandas as pd
df=pd.read_csv("transactions.csv")
df
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
df.describe()
# Out:
#        TransactionID    UserID  ProductID   Quantity
# count       10.00000  9.000000  10.000000  10.000000
# mean         5.50000  3.444444   3.400000   2.400000
# std          3.02765  2.127858   1.074968   1.712698
# min          1.00000  1.000000   2.000000   1.000000
# 25%          3.25000  2.000000   2.250000   1.000000
# 50%          5.50000  3.000000   4.000000   2.000000
# 75%          7.75000  3.000000   4.000000   3.000000
# max         10.00000  7.000000   5.000000   6.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4>

# %%
len(df.columns)
# Out:
# 5

# %%
len(df.index)
# Out:
# 10

# %%
df.shape
# Out:
# (10, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'UserID', 'ProductID', 'Quantity'], dtype='object')

# %%
df.rename(columns={"Quantity":"Quant"},inplace=True)

# %%
df
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quant
# 0              1      2010-08-21     7.0          2      1
# 1              2      2011-05-26     3.0          4      1
# 2              3      2011-06-16     3.0          3      1
# 3              4      2012-08-26     1.0          2      3
# 4              5      2013-06-06     2.0          4      1
# 5              6      2013-12-23     2.0          5      6
# 6              7      2013-12-30     3.0          4      1
# 7              8      2014-04-24     NaN          2      3
# 8              9      2015-04-24     7.0          4      3
# 9             10      2016-05-08     3.0          4      4

# %%
df.rename(columns={"ProductID":"PID","UserID":"UID"},inplace=True)

# %%
df
# Out:
#    TransactionID TransactionDate  UID  PID  Quant
# 0              1      2010-08-21  7.0    2      1
# 1              2      2011-05-26  3.0    4      1
# 2              3      2011-06-16  3.0    3      1
# 3              4      2012-08-26  1.0    2      3
# 4              5      2013-06-06  2.0    4      1
# 5              6      2013-12-23  2.0    5      6
# 6              7      2013-12-30  3.0    4      1
# 7              8      2014-04-24  NaN    2      3
# 8              9      2015-04-24  7.0    4      3
# 9             10      2016-05-08  3.0    4      4

# %%
df=df.sort_values(by=["TransactionID"],ascending=False)

# %%
df
# Out:
#    TransactionID TransactionDate  UID  PID  Quant
# 9             10      2016-05-08  3.0    4      4
# 8              9      2015-04-24  7.0    4      3
# 7              8      2014-04-24  NaN    2      3
# 6              7      2013-12-30  3.0    4      1
# 5              6      2013-12-23  2.0    5      6
# 4              5      2013-06-06  2.0    4      1
# 3              4      2012-08-26  1.0    2      3
# 2              3      2011-06-16  3.0    3      1
# 1              2      2011-05-26  3.0    4      1
# 0              1      2010-08-21  7.0    2      1

# %%
df=df.sort_values(by=["Quant","TransactionDate"],ascending=[True,False])
df
# Out:
#    TransactionID TransactionDate  UID  PID  Quant
# 6              7      2013-12-30  3.0    4      1
# 4              5      2013-06-06  2.0    4      1
# 2              3      2011-06-16  3.0    3      1
# 1              2      2011-05-26  3.0    4      1
# 0              1      2010-08-21  7.0    2      1
# 8              9      2015-04-24  7.0    4      3
# 7              8      2014-04-24  NaN    2      3
# 3              4      2012-08-26  1.0    2      3
# 9             10      2016-05-08  3.0    4      4
# 5              6      2013-12-23  2.0    5      6

# %%
df=df[["PID","Quant","TransactionDate","TransactionID","UID"]]
df
# Out:
#    PID  Quant TransactionDate  TransactionID  UID
# 6    4      1      2013-12-30              7  3.0
# 4    4      1      2013-06-06              5  2.0
# 2    3      1      2011-06-16              3  3.0
# 1    4      1      2011-05-26              2  3.0
# 0    2      1      2010-08-21              1  7.0
# 8    4      3      2015-04-24              9  7.0
# 7    2      3      2014-04-24              8  NaN
# 3    2      3      2012-08-26              4  1.0
# 9    4      4      2016-05-08             10  3.0
# 5    5      6      2013-12-23              6  2.0

# %%
df=df[["UID"]+[col for col in df.columns if col!="UID"]]

# %%
df
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 4  2.0    4      1      2013-06-06              5
# 2  3.0    3      1      2011-06-16              3
# 1  3.0    4      1      2011-05-26              2
# 0  7.0    2      1      2010-08-21              1
# 8  7.0    4      3      2015-04-24              9
# 7  NaN    2      3      2014-04-24              8
# 3  1.0    2      3      2012-08-26              4
# 9  3.0    4      4      2016-05-08             10
# 5  2.0    5      6      2013-12-23              6

# %%
df.iloc[:,1]
# Out:
# 6    4
# 4    4
# 2    3
# 1    4
# 0    2
# 8    4
# 7    2
# 3    2
# 9    4
# 5    5
# Name: PID, dtype: int64

# %%
import numpy as np
arr=np.array(df[["PID"]])
arr
# Out:
# array([[4],
#        [4],
#        [3],
#        [4],
#        [2],
#        [4],
#        [2],
#        [2],
#        [4],
#        [5]])

# %%
rows=[1,3,6]
df.iloc[rows]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 4  2.0    4      1      2013-06-06              5
# 1  3.0    4      1      2011-05-26              2
# 7  NaN    2      3      2014-04-24              8

# %%
df.iloc[[row for row in df.index if row not in rows]]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 0  7.0    2      1      2010-08-21              1
# 2  3.0    3      1      2011-06-16              3
# 6  3.0    4      1      2013-12-30              7
# 9  3.0    4      4      2016-05-08             10
# 3  1.0    2      3      2012-08-26              4
# 5  2.0    5      6      2013-12-23              6
# 8  7.0    4      3      2015-04-24              9

# %%
df.iloc[0:3,:]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 4  2.0    4      1      2013-06-06              5
# 2  3.0    3      1      2011-06-16              3

# %%
n=len(df.index)
last_rows=[n-1,n-2]
last_rows
# Out:
# [9, 8]

# %%
df.iloc[[row for row in df.index if row not in last_rows]]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 7  NaN    2      3      2014-04-24              8
# 0  7.0    2      1      2010-08-21              1
# 2  3.0    3      1      2011-06-16              3
# 4  2.0    4      1      2013-06-06              5
# 6  3.0    4      1      2013-12-30              7
# 3  1.0    2      3      2012-08-26              4
# 1  3.0    4      1      2011-05-26              2
# 8  7.0    4      3      2015-04-24              9

# %%
df.iloc[0:n-2,:]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 4  2.0    4      1      2013-06-06              5
# 2  3.0    3      1      2011-06-16              3
# 1  3.0    4      1      2011-05-26              2
# 0  7.0    2      1      2010-08-21              1
# 8  7.0    4      3      2015-04-24              9
# 7  NaN    2      3      2014-04-24              8
# 3  1.0    2      3      2012-08-26              4

# %%
df.iloc[3:,:]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 1  3.0    4      1      2011-05-26              2
# 0  7.0    2      1      2010-08-21              1
# 8  7.0    4      3      2015-04-24              9
# 7  NaN    2      3      2014-04-24              8
# 3  1.0    2      3      2012-08-26              4
# 9  3.0    4      4      2016-05-08             10
# 5  2.0    5      6      2013-12-23              6

# %%
df[df["Quant"]>1]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 8  7.0    4      3      2015-04-24              9
# 7  NaN    2      3      2014-04-24              8
# 3  1.0    2      3      2012-08-26              4
# 9  3.0    4      4      2016-05-08             10
# 5  2.0    5      6      2013-12-23              6

# %%
df[df["UID"]==2]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 4  2.0    4      1      2013-06-06              5
# 5  2.0    5      6      2013-12-23              6

# %%
df[(df["Quant"]>1) & (df["UID"]>3)]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 8  7.0    4      3      2015-04-24              9

# %%
df_h=df.head(4)
foo=[True,False,True,True]
df_h[foo]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 2  3.0    3      1      2011-06-16              3
# 1  3.0    4      1      2011-05-26              2

# %%
bar=[1,0,-2,3]
bar=np.array(bar)
df_h[bar>0]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 1  3.0    4      1      2011-05-26              2

# %%
df_h[(foo) | (bar<0)]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 2  3.0    3      1      2011-06-16              3
# 1  3.0    4      1      2011-05-26              2

# %%
df_h[(foo)&(bar<0)]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 2  3.0    3      1      2011-06-16              3

# %%
df.iloc[:,[1,3]]
# Out:
#    PID TransactionDate
# 6    4      2013-12-30
# 4    4      2013-06-06
# 2    3      2011-06-16
# 1    4      2011-05-26
# 0    2      2010-08-21
# 8    4      2015-04-24
# 7    2      2014-04-24
# 3    2      2012-08-26
# 9    4      2016-05-08
# 5    5      2013-12-23

# %%
df.iloc[:,~[1,3]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0c294b02b19e> in <module>
# ----> 1 df.iloc[:,~[1,3]]
#
# TypeError: bad operand type for unary ~: 'list'

# %%
df.iloc[[1,3,6],:]
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 4  2.0    4      1      2013-06-06              5
# 1  3.0    4      1      2011-05-26              2
# 7  NaN    2      3      2014-04-24              8

# %%
df[df['Quant']>1][["Quant","TransactionID","TransactionDate"]]
# Out:
#    Quant  TransactionID TransactionDate
# 8      3              9      2015-04-24
# 7      3              8      2014-04-24
# 3      3              4      2012-08-26
# 9      4             10      2016-05-08
# 5      6              6      2013-12-23

# %%
df[["Quant","PID"]]
# Out:
#    Quant  PID
# 6      1    4
# 4      1    4
# 2      1    3
# 1      1    4
# 0      1    2
# 8      3    4
# 7      3    2
# 3      3    2
# 9      4    4
# 5      6    5

# %%
cols=["Quant","PID"]
df[[col for col in df.columns if col not in cols]]
# Out:
#    UID TransactionDate  TransactionID
# 6  3.0      2013-12-30              7
# 4  2.0      2013-06-06              5
# 2  3.0      2011-06-16              3
# 1  3.0      2011-05-26              2
# 0  7.0      2010-08-21              1
# 8  7.0      2015-04-24              9
# 7  NaN      2014-04-24              8
# 3  1.0      2012-08-26              4
# 9  3.0      2016-05-08             10
# 5  2.0      2013-12-23              6

# %%
df
# Out:
#    UID  PID  Quant TransactionDate  TransactionID
# 6  3.0    4      1      2013-12-30              7
# 4  2.0    4      1      2013-06-06              5
# 2  3.0    3      1      2011-06-16              3
# 1  3.0    4      1      2011-05-26              2
# 0  7.0    2      1      2010-08-21              1
# 8  7.0    4      3      2015-04-24              9
# 7  NaN    2      3      2014-04-24              8
# 3  1.0    2      3      2012-08-26              4
# 9  3.0    4      4      2016-05-08             10
# 5  2.0    5      6      2013-12-23              6

# %%
df["TransactionDate"]=pd.to_datetime(df["TransactionDate"],errors="coerce")
df["TransactionDate"]=df["TransactionDate"].dt.date
from datetime import datetime
df.loc[len(df)]=[9,6,2,datetime.strptime("2003-01-24","%Y-%m-%d").date(),9]

# %%
df
# Out:
#     UID  PID  Quant TransactionDate  TransactionID
# 6   3.0    4      1      2013-12-30              7
# 4   2.0    4      1      2013-06-06              5
# 2   3.0    3      1      2011-06-16              3
# 1   3.0    4      1      2011-05-26              2
# 0   7.0    2      1      2010-08-21              1
# 8   7.0    4      3      2015-04-24              9
# 7   NaN    2      3      2014-04-24              8
# 3   1.0    2      3      2012-08-26              4
# 9   3.0    4      4      2016-05-08             10
# 5   2.0    5      6      2013-12-23              6
# 10  9.0    6      2      2003-01-24              9

# %%
df.loc[df["Quant"]==6,"Quant"]=1

# %%
df
# Out:
#     UID  PID  Quant TransactionDate  TransactionID
# 6   3.0    4      1      2013-12-30              7
# 4   2.0    4      1      2013-06-06              5
# 2   3.0    3      1      2011-06-16              3
# 1   3.0    4      1      2011-05-26              2
# 0   7.0    2      1      2010-08-21              1
# 8   7.0    4      3      2015-04-24              9
# 7   NaN    2      3      2014-04-24              8
# 3   1.0    2      3      2012-08-26              4
# 9   3.0    4      4      2016-05-08             10
# 5   2.0    5      1      2013-12-23              6
# 10  9.0    6      2      2003-01-24              9

# %%
df["foo"]=df["UID"]+df["PID"]

# %%
df
# Out:
#     UID  PID  Quant TransactionDate  TransactionID   foo
# 6   3.0    4      1      2013-12-30              7   7.0
# 4   2.0    4      1      2013-06-06              5   6.0
# 2   3.0    3      1      2011-06-16              3   6.0
# 1   3.0    4      1      2011-05-26              2   7.0
# 0   7.0    2      1      2010-08-21              1   9.0
# 8   7.0    4      3      2015-04-24              9  11.0
# 7   NaN    2      3      2014-04-24              8   NaN
# 3   1.0    2      3      2012-08-26              4   3.0
# 9   3.0    4      4      2016-05-08             10   7.0
# 5   2.0    5      1      2013-12-23              6   7.0
# 10  9.0    6      2      2003-01-24              9  15.0

# %%
df.iloc[:,[i for i in range(df.shape[1]) if i not in [1,3,6]]]
# Out:
#     UID  Quant  TransactionID   foo
# 6   3.0      1              7   7.0
# 4   2.0      1              5   6.0
# 2   3.0      1              3   6.0
# 1   3.0      1              2   7.0
# 0   7.0      1              1   9.0
# 8   7.0      3              9  11.0
# 7   NaN      3              8   NaN
# 3   1.0      3              4   3.0
# 9   3.0      4             10   7.0
# 5   2.0      1              6   7.0
# 10  9.0      2              9  15.0

# %%
df
# Out:
#     UID  PID  Quant TransactionDate  TransactionID   foo
# 6   3.0    4      1      2013-12-30              7   7.0
# 4   2.0    4      1      2013-06-06              5   6.0
# 2   3.0    3      1      2011-06-16              3   6.0
# 1   3.0    4      1      2011-05-26              2   7.0
# 0   7.0    2      1      2010-08-21              1   9.0
# 8   7.0    4      3      2015-04-24              9  11.0
# 7   NaN    2      3      2014-04-24              8   NaN
# 3   1.0    2      3      2012-08-26              4   3.0
# 9   3.0    4      4      2016-05-08             10   7.0
# 5   2.0    5      1      2013-12-23              6   7.0
# 10  9.0    6      2      2003-01-24              9  15.0

# %%
newrow={'UID':10,'PID':4,'Quant':2,'TransactionDate':"2005-06-20",'foo':None}

# %%
df.loc[len(df)]=[10,4,2,datetime.strptime("2005-06-20","%Y-%m-%d").date(),3,None]

# %%
df
# Out:
#      UID  PID  Quant                                    TransactionDate  \
# 6    3.0    4      1                                         2013-12-30
# 4    2.0    4      1                                         2013-06-06
# 2    3.0    3      1                                         2011-06-16
# 1    3.0    4      1                                         2011-05-26
# 0    7.0    2      1                                         2010-08-21
# 8    7.0    4      3                                         2015-04-24
# 7    NaN    2      3                                         2014-04-24
# 3    1.0    2      3                                         2012-08-26
# 9    3.0    4      4                                         2016-05-08
# 5    2.0    5      1                                         2013-12-23
# 10   9.0    6      2                                         2003-01-24
# 11  10.0    4      2  <built-in method date of datetime.datetime obj...
# ...
